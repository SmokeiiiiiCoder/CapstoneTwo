# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
#import the data
path_s = './data/supplemental_files/'
path_t = './data/train_files/'
path_e = './data/example_test_files/'

# %%
prices1 = pd.read_csv(f'{path_t}stock_prices.csv')
prices2 = pd.read_csv(f'{path_t}secondary_stock_prices.csv')

prices1.shape , prices2.shape
# Out:
# ((2332531, 12), (2384575, 12))

# %%
#combine all data together
df = pd.concat([prices1,prices2])
df
# Out:
#                   RowId        Date  SecuritiesCode    Open    High     Low  \
# 0         20170104_1301  2017-01-04            1301  2734.0  2755.0  2730.0
# 1         20170104_1332  2017-01-04            1332   568.0   576.0   563.0
# 2         20170104_1333  2017-01-04            1333  3150.0  3210.0  3140.0
# 3         20170104_1376  2017-01-04            1376  1510.0  1550.0  1510.0
# 4         20170104_1377  2017-01-04            1377  3270.0  3350.0  3270.0
# ...                 ...         ...             ...     ...     ...     ...
# 2384570   20211203_9980  2021-12-03            9980   129.0   131.0   129.0
# 2384571   20211203_9986  2021-12-03            9986  1900.0  1900.0  1891.0
# 2384572   20211203_9995  2021-12-03            9995   390.0   395.0   388.0
# 2384573   20211203_9996  2021-12-03            9996  1490.0  1500.0  1490.0
# 2384574  20211203_25935  2021-12-03           25935  1995.0  2009.0  1993.0
#
# ...

# %%
#getting more information to understand the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4717106 entries, 0 to 2384574
# Data columns (total 12 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   RowId             object
#  1   Date              object
#  2   SecuritiesCode    int64
#  3   Open              float64
#  4   High              float64
#  5   Low               float64
#  6   Close             float64
#  7   Volume            int64
#  8   AdjustmentFactor  float64
#  9   ExpectedDividend  float64
#  10  SupervisionFlag   bool
#  11  Target            float64
# dtypes: bool(1), float64(7), int64(2), object(2)
# memory usage: 436.4+ MB

# %%
df.nunique()
# Out:
# RowId               4717106
# Date                   1202
# SecuritiesCode         4371
# Open                  26256
# High                  27166
# Low                   27110
# Close                 27258
# Volume               154518
# AdjustmentFactor         24
# ExpectedDividend       1348
# SupervisionFlag           2
# Target               430278
# dtype: int64

# %%
df[df['AdjustmentFactor']==5]
# Out:
#                  RowId        Date  SecuritiesCode    Open    High     Low  \
# 16346    20170117_8057  2017-01-17            8057   498.0   498.0   490.0
# 107318   20170328_6277  2017-03-28            6277   885.0   894.0   883.0
# 222801   20170627_1899  2017-06-27            1899  1077.0  1079.0  1070.0
# 223249   20170627_4025  2017-06-27            4025   896.0   902.0   895.0
# 223517   20170627_5201  2017-06-27            5201   941.0   952.0   941.0
# ...                ...         ...             ...     ...     ...     ...
# 824061   20180925_7877  2018-09-25            7877   358.0   362.0   358.0
# 824123   20180925_8085  2018-09-25            8085   403.0   408.0   401.0
# 1020147  20190225_3647  2019-02-25            3647    63.0    64.0    63.0
# 1695031  20200717_6628  2020-07-17            6628    10.0    11.0    10.0
# 1787657  20200928_8704  2020-09-28            8704    79.0    88.0    79.0
#
#           Close    Volume  AdjustmentFactor  ExpectedDividend  \
# ...

# %%
#check for na in rowid
#df['RowId'].isnull().sum() #0
#check for dupilcate rowid
#df['RowId'].count() == df['RowId'].nunique()#True

# %%
#calculate high-low as performance in one day
df['Performance'] = (df['High'] - df['Low'])/df['Volume']

# %%
corr = df.corr()
f, ax = plt.subplots(figsize=(12, 9))
hm = sns.heatmap(corr, annot=True, ax=ax, cmap="coolwarm",fmt='.2f',
                 linewidths=.05)
